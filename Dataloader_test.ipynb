# %%
import torch
import json
import numpy as np
import os
import os.path as osp

# %%
root_path = osp.join('/media', '3_4T', 'COCO')

# %%
annot_path = osp.join(root_path, 'annotations', 'person_keypoints_train2017.json')

# %%
with open(annot_path, 'r') as f:
    annot = json.load(f)

# %%
annot['annotations'][0]['bbox']
# Out:
# [267.03, 104.32, 229.19, 320]

# %%
annot['images'][0].keys()
# Out:
# dict_keys(['license', 'file_name', 'coco_url', 'height', 'width', 'date_captured', 'flickr_url', 'id'])

# %%
len(annot['info'])
# Out:
# 6

# %%
annot.keys()
# Out:
# dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %%
annot['annotations'][0].keys()
# Out:
# dict_keys(['segmentation', 'num_keypoints', 'area', 'iscrowd', 'keypoints', 'image_id', 'bbox', 'category_id', 'id'])

# %%
annot['annotations'][0]['id']
# Out:
# 183020

# %%
annot['annotations'][0]['image_id']
# Out:
# 537548

# %%
annot['images'][0]['id']
# Out:
# 391895

# %%
from pycocotools.coco import COCO

# %%
coco=COCO(annot_path)
# Out:
# loading annotations into memory...
# Done (t=4.11s)
# creating index...
# index created!

# %%
catIds = coco.getCatIds(catNms=['person'])

# %%
imgIds = coco.getImgIds(catIds=catIds)

# %%
img = coco.loadImgs(imgIds[0])[0]

# %%
img.keys()
# Out:
# dict_keys(['license', 'file_name', 'coco_url', 'height', 'width', 'date_captured', 'flickr_url', 'id'])

# %%
img['id']
# Out:
# 262145

# %%
imgIds[0]
# Out:
# 262145

# %%
import matplotlib.pyplot as plt
import skimage.io as io

# %%
# load and display image
# I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
# use url to load image
I = io.imread(img['coco_url'])
plt.axis('off')
plt.imshow(I)
plt.show()

# %%
# load and display instance annotations
plt.imshow(I)
plt.axis('off')
annIds = coco.getAnnIds(imgIds=img['id'], catIds=catIds, iscrowd=None)
anns = coco.loadAnns(annIds)
coco.showAnns(anns)

# %%
bboxes = []
for ann in anns:
    bboxes.append(ann['bbox'])

# %%
anns[13]['image_id']
# Out:
# 262145

# %%
def showbboxes(anns)

# %%
anns = coco.loadAnns(annIds)

# %%
annIds
# Out:
# [1218400,
#  1220136,
#  1246711,
#  1249960,
#  1262984,
#  1266299,
#  1293147,
#  1302954,
#  1311644,
#  1314438,
#  1321931,
#  1731447,
#  2025332,
#  900100262145]

# %%
anns[0].keys()
# Out:
# dict_keys(['segmentation', 'num_keypoints', 'area', 'iscrowd', 'keypoints', 'image_id', 'bbox', 'category_id', 'id'])

# %%
len(anns)
# Out:
# 14

# %%
class Dataloader_COCO(torch.utils.data.Dataset):
    def __init__(self):
        self.img_path = osp.join(root_path, 'images')
        self.annot_path = osp.join(root_path, 'annotations')
    def __getitem__(self, index):
        return 0
    def __len__(self):
        return 0
